# %% [markdown]
# # Tarea 7:

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
data = [df.loc[:,'peso'],]
patches = plt.hist(data, bins = 15)

# %%
sns.lmplot(x = 'sistol',
           y = 'diastol',
           data = df,
           fit_reg = False,
           hue = 'sexo'
          )
plt.title('Scatterplot of sistol vs diastol')
# Out:
# Text(0.5, 1.0, 'Scatterplot of sistol vs diastol')

# %%
sns.boxplot(data = df.loc[:,['cintura']])

# %%
tabla = df.loc[df['sexo']==2, ['sistol','diastol']]
tabla
# Out:
#        sistol  diastol
# 0       63.25    53.25
# 1       70.00    50.00
# 2       70.50    41.00
# 4       72.00    53.50
# 6       74.00    39.00
# ...       ...      ...
# 18633  216.00   101.50
# 18635  221.00    95.50
# 18636  222.25    78.00
# 18638  235.00   100.00
# 18639  240.00   150.00
#
# [10486 rows x 2 columns]

# %%
sns.lmplot(x = 'sistol',
           y = 'diastol',
           fit_reg = False,
           data = tabla)

# %%
tabla2 = df.loc[df['sexo']==1,['cintura']]
tabla2
# Out:
#        cintura
# 3        60.60
# 5        59.50
# 9        79.65
# 17       60.70
# 21       96.20
# ...        ...
# 18626   104.25
# 18627   100.75
# 18630    83.60
# 18634   132.00
# 18637    71.35
#
# [8154 rows x 1 columns]

# %%
data = [tabla2.loc[:,'cintura'],]
patches = plt.hist(data, bins = 25)
